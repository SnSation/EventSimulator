# %%
import Gauntlets
import math
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
new_gauntlet = Gauntlets.GauntletApp(0)

# %%
new_gauntlet.new_random_event()

# %%
new_gauntlet.current_event
# Out:
# <Event | ID: 619169 | Owner ID: 0>

# %%
new_gauntlet.run_event()
# Out:
# Running Event: <Event | ID: 619169 | Owner ID: 0>
# Start Time: 2021-01-05 03:21:46.602218
# End Time: 2021-01-05 03:21:46.602218
# Test Time: 0:00:05.046629
# Rows Generated: 1684800

# %%
new_gauntlet.runs
# Out:
# [{'stats': {'influencer': <Influencer | ID: 0 | Owner ID: 0>,
#    'gauntlet_difficulty': 6.2,
#    'average_attributes': {'minor_1': 6.8,
#     'minor_2': 5.0,
#     'minor_3': 5.7,
#     'minor_4': 21872.2,
#     'major': 21872.2}},
#   'data': {1: [1,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     1,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    2: [2,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     1,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    3: [3,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     1,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    4: [4,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     1,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    5: [5,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     1,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    6: [6,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     1,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    7: [7,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     1,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    8: [8,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     1,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    9: [9,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     1,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    10: [10,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     1,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    11: [11,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     2,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    12: [12,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     2,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    13: [13,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     2,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    14: [14,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     2,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    15: [15,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     2,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    16: [16,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     2,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    17: [17,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     2,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    18: [18,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     2,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    19: [19,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     2,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    20: [20,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     2,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    21: [21,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     3,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    22: [22,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     3,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    23: [23,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     3,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    24: [24,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     3,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    25: [25,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     3,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    26: [26,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     3,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    27: [27,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     3,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    28: [28,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     3,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    29: [29,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     3,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    30: [30,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     3,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    31: [31,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     4,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    32: [32,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     4,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    33: [33,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     4,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    34: [34,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     4,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    35: [35,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     4,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    36: [36,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     4,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    37: [37,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     4,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    38: [38,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     4,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    39: [39,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     4,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    40: [40,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     4,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    41: [41,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     5,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    42: [42,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     5,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    43: [43,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     5,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    44: [44,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     5,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    45: [45,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     5,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    46: [46,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     5,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    47: [47,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     5,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    48: [48,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     5,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    49: [49,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     5,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    50: [50,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     5,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    51: [51,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     6,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    52: [52,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     6,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    53: [53,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     6,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    54: [54,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     6,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    55: [55,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     6,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    56: [56,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     6,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    57: [57,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     6,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    58: [58,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     6,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    59: [59,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     6,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    60: [60,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     6,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    61: [61,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     7,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    62: [62,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     7,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    63: [63,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     7,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    64: [64,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     7,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    65: [65,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     7,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    66: [66,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     7,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    67: [67,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     7,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    68: [68,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     7,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    69: [69,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     7,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    70: [70,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     7,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    71: [71,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     8,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    72: [72,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     8,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    73: [73,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     8,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    74: [74,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     8,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    75: [75,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     8,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    76: [76,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     8,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    77: [77,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     8,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    78: [78,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     8,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    79: [79,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     8,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    80: [80,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     8,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    81: [81,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     9,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    82: [82,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     9,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    83: [83,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     9,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    84: [84,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     9,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    85: [85,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     9,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    86: [86,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     9,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    87: [87,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     9,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    88: [88,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     9,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    89: [89,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     9,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    90: [90,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     9,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    91: [91,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     10,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    92: [92,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     10,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    93: [93,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     10,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    94: [94,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     10,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    95: [95,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     10,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    96: [96,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     10,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    97: [97,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     10,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    98: [98,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     10,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    99: [99,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     10,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    100: [100,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     10,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    101: [101,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     11,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    102: [102,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     11,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    103: [103,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     11,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    104: [104,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     11,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    105: [105,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     11,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    106: [106,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     11,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    107: [107,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     11,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    108: [108,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     11,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    109: [109,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     11,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    110: [110,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     11,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    111: [111,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     12,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    112: [112,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     12,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    113: [113,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     12,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    114: [114,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     12,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    115: [115,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     12,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    116: [116,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     12,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    117: [117,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     12,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    118: [118,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     12,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    119: [119,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     12,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    120: [120,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     12,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    121: [121,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     13,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    122: [122,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     13,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    123: [123,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     13,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    124: [124,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     13,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    125: [125,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     13,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    126: [126,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     13,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    127: [127,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     13,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    128: [128,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     13,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    129: [129,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     13,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    130: [130,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     13,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    131: [131,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     14,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    132: [132,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     14,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    133: [133,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     14,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    134: [134,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     14,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    135: [135,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     14,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    136: [136,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     14,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    137: [137,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     14,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    138: [138,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     14,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    139: [139,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     14,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    140: [140,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     14,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    141: [141,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     15,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    142: [142,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     15,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    143: [143,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     15,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    144: [144,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     15,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    145: [145,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     15,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    146: [146,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     15,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    147: [147,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     15,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    148: [148,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     15,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    149: [149,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     15,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    150: [150,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     15,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    151: [151,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     16,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    152: [152,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     16,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    153: [153,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     16,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    154: [154,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     16,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    155: [155,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     16,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    156: [156,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     16,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    157: [157,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     16,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    158: [158,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     16,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    159: [159,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     16,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    160: [160,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     16,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    161: [161,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     17,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    162: [162,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     17,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    163: [163,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     17,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    164: [164,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     17,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    165: [165,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     17,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    166: [166,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     17,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    167: [167,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     17,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    168: [168,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     17,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    169: [169,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     17,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    170: [170,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     17,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    171: [171,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     18,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    172: [172,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     18,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    173: [173,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     18,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    174: [174,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     18,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    175: [175,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     18,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    176: [176,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     18,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    177: [177,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     18,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    178: [178,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     18,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    179: [179,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     18,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    180: [180,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     18,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    181: [181,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     19,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    182: [182,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     19,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    183: [183,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     19,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    184: [184,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     19,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    185: [185,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     19,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    186: [186,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     19,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    187: [187,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     19,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    188: [188,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     19,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    189: [189,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     19,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    190: [190,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     19,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    191: [191,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     20,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    192: [192,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     20,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    193: [193,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     20,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    194: [194,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     20,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    195: [195,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     20,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    196: [196,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     20,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    197: [197,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     20,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    198: [198,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     20,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    199: [199,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     20,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    200: [200,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     20,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    201: [201,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     21,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    202: [202,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     21,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    203: [203,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     21,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    204: [204,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     21,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    205: [205,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     21,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    206: [206,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     21,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    207: [207,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     21,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    208: [208,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     21,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    209: [209,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     21,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    210: [210,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     21,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    211: [211,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     22,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    212: [212,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     22,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    213: [213,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     22,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    214: [214,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     22,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    215: [215,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     22,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    216: [216,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     22,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    217: [217,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     22,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    218: [218,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     22,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    219: [219,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     22,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    220: [220,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     22,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    221: [221,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     23,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    222: [222,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     23,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    223: [223,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     23,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    224: [224,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     23,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    225: [225,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     23,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    226: [226,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     23,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    227: [227,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     23,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    228: [228,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     23,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    229: [229,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     23,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    230: [230,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     23,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    231: [231,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     24,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    232: [232,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     24,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    233: [233,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     24,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    234: [234,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     24,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    235: [235,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     24,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    236: [236,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     24,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    237: [237,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     24,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    238: [238,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     24,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    239: [239,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     24,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    240: [240,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     24,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    241: [241,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     25,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    242: [242,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     25,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    243: [243,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     25,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    244: [244,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     25,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    245: [245,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     25,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    246: [246,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     25,
#     1,
#     'twistiest',
# ...
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    920: [920,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     92,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    921: [921,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     93,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    922: [922,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     93,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    923: [923,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     93,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    924: [924,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     93,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    925: [925,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     93,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    926: [926,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     93,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    927: [927,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     93,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    928: [928,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     93,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    929: [929,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     93,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    930: [930,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     93,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    931: [931,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     94,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    932: [932,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     94,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    933: [933,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     94,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    934: [934,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     94,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    935: [935,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     94,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    936: [936,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     94,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    937: [937,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     94,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    938: [938,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     94,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    939: [939,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     94,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    940: [940,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     94,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    941: [941,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     95,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    942: [942,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     95,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    943: [943,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     95,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    944: [944,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     95,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    945: [945,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     95,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    946: [946,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     95,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    947: [947,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     95,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    948: [948,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     95,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    949: [949,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     95,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    950: [950,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     95,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    951: [951,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     96,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    952: [952,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     96,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    953: [953,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     96,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    954: [954,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     96,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    955: [955,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     96,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    956: [956,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     96,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    957: [957,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     96,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    958: [958,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     96,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    959: [959,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     96,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    960: [960,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     96,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    961: [961,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     97,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    962: [962,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     97,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    963: [963,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     97,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    964: [964,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     97,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    965: [965,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     97,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    966: [966,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     97,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    967: [967,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     97,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    968: [968,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     97,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    969: [969,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     97,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    970: [970,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     97,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    971: [971,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     98,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    972: [972,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     98,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    973: [973,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     98,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    974: [974,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     98,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    975: [975,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     98,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    976: [976,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     98,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    977: [977,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     98,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    978: [978,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     98,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    979: [979,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     98,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    980: [980,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     98,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    981: [981,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     99,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    982: [982,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     99,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    983: [983,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     99,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    984: [984,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     99,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    985: [985,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     99,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    986: [986,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     99,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    987: [987,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     99,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    988: [988,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     99,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    989: [989,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     99,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    990: [990,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     99,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    991: [991,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     100,
#     1,
#     'grinning',
#     'trashily',
#     'resting',
#     0,
#     36207.0,
#     8,
#     5,
#     4,
#     36207,
#     36207],
#    992: [992,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     100,
#     1,
#     'acaudate',
#     'frenchification',
#     'resting',
#     0,
#     26017.0,
#     9,
#     5,
#     10,
#     26017,
#     26017],
#    993: [993,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     100,
#     1,
#     'touchline',
#     'spermic',
#     'resting',
#     0,
#     21866.0,
#     6,
#     1,
#     8,
#     21866,
#     21866],
#    994: [994,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     100,
#     1,
#     'snakeheads',
#     'wadies',
#     'resting',
#     0,
#     19268.0,
#     9,
#     1,
#     6,
#     19268,
#     19268],
#    995: [995,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     100,
#     1,
#     'weekenders',
#     'lempira',
#     'resting',
#     0,
#     6540.0,
#     4,
#     10,
#     5,
#     6540,
#     6540],
#    996: [996,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     100,
#     1,
#     'twistiest',
#     'goosefishes',
#     'resting',
#     0,
#     39101.0,
#     8,
#     10,
#     8,
#     39101,
#     39101],
#    997: [997,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     100,
#     1,
#     'interannual',
#     'dowelling',
#     'resting',
#     0,
#     1126.0,
#     5,
#     5,
#     2,
#     1126,
#     1126],
#    998: [998,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     100,
#     1,
#     'papain',
#     'mowing',
#     'resting',
#     0,
#     7036.0,
#     4,
#     4,
#     2,
#     7036,
#     7036],
#    999: [999,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     100,
#     1,
#     'prearms',
#     'nonresistance',
#     'resting',
#     0,
#     20437.0,
#     5,
#     3,
#     7,
#     20437,
#     20437],
#    1000: [1000,
#     'blemishes',
#     'incentivizes',
#     'immingling',
#     100,
#     1,
#     'prude',
#     'cassavas',
#     'resting',
#     0,
#     41124.0,
#     10,
#     6,
#     5,
#     41124,
#     41124],
#    ...}}]

# %%
new_gauntlet.current_event.teams[0].participants[0].attributes
# Out:
# {'minor_1': 8, 'minor_2': 5, 'minor_3': 4, 'minor_4': 36207, 'major': 36207}

# %%
data_points = ['index', 'event', 'gauntlet', 'trial', 'time', 'day', 'participant_first_name', 'participant_last_name', 'status', 'perfect_progress', 'success_value', 'influencer_first_name', 'influencer_last_name', 'influencer_attribute_1', 'influencer_attribute_2']

for attribute in new_gauntlet.current_event.teams[0].participants[0].attributes.keys():
    data_points.append(f'participant_{attribute}')

test_data = pd.DataFrame.from_dict(new_gauntlet.runs[0]['data'], orient='index', columns=data_points)

# %%
test_data
# Out:
#            index      event      gauntlet       trial    time  day  \
# 1              1  blemishes  incentivizes  immingling       1    1
# 2              2  blemishes  incentivizes  immingling       1    1
# 3              3  blemishes  incentivizes  immingling       1    1
# 4              4  blemishes  incentivizes  immingling       1    1
# 5              5  blemishes  incentivizes  immingling       1    1
# ...          ...        ...           ...         ...     ...  ...
# 1684796  1684796  blemishes  incentivizes  binucleate  168480  118
# 1684797  1684797  blemishes  incentivizes  binucleate  168480  118
# 1684798  1684798  blemishes  incentivizes  binucleate  168480  118
# 1684799  1684799  blemishes  incentivizes  binucleate  168480  118
# 1684800  1684800  blemishes  incentivizes  binucleate  168480  118
#
#           first_name        last_name   status  perfect_progress  \
# 1           grinning         trashily  resting                 0
# 2           acaudate  frenchification  resting                 0
# 3          touchline          spermic  resting                 0
# 4         snakeheads           wadies  resting                 0
# 5         weekenders          lempira  resting                 0
# ...              ...              ...      ...               ...
# 1684796    twistiest      goosefishes  resting           4032000
# 1684797  interannual        dowelling  resting           4032000
# 1684798       papain           mowing  resting           4032000
# 1684799      prearms    nonresistance  resting           4032000
# 1684800        prude         cassavas  resting           4032000
#
#          success_value  minor_1  minor_2  minor_3  minor_4  major
# 1             36207.00        8        5        4    36207  36207
# 2             26017.00        9        5       10    26017  26017
# 3             21866.00        6        1        8    21866  21866
# 4             19268.00        9        1        6    19268  19268
# 5              6540.00        4       10        5     6540   6540
# ...                ...      ...      ...      ...      ...    ...
# 1684796           0.01        8       10        8    39101  39101
# 1684797           0.00        5        5        2     1126   1126
# 1684798           0.00        4        4        2     7036   7036
# 1684799           0.01        5        3        7    20437  20437
# 1684800           0.01       10        6        5    41124  41124
#
# [1684800 rows x 16 columns]
