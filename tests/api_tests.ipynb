# %%
import requests
import pandas as pd

# %%
test_event = requests.get('http://127.0.0.1:5000/api/single_event/2').json()

test_event
# Out:
# {'description': 'Event_Description_0',
#  'gauntlets': [{'description': 'fragmentary',
#    'duration': 2822400,
#    'name': 'crumbs',
#    'trials': [{'description': 'Description_30',
#      'dificulty': 4,
#      'duration': 28800,
#      'id': 31,
#      'name': 'Trial_30'},
#     {'description': 'Description_27',
#      'dificulty': 3,
#      'duration': 230400,
#      'id': 28,
#      'name': 'Trial_27'},
#     {'description': 'Description_23',
#      'dificulty': 3,
#      'duration': 115200,
#      'id': 24,
#      'name': 'Trial_23'},
#     {'description': 'Description_66',
#      'dificulty': 7,
#      'duration': 201600,
#      'id': 67,
#      'name': 'Trial_66'},
#     {'description': 'Description_93',
#      'dificulty': 10,
#      'duration': 115200,
#      'id': 94,
#      'name': 'Trial_93'},
#     {'description': 'Description_47',
#      'dificulty': 5,
#      'duration': 230400,
#      'id': 48,
#      'name': 'Trial_47'},
#     {'description': 'Description_96',
# ...

# %%
description = test_event['description']
description
# Out:
# 'Event_Description_0'

# %%
gauntlets = test_event['gauntlets']
gauntlets
# Out:
# [{'description': 'fragmentary',
#   'duration': 2822400,
#   'name': 'crumbs',
#   'trials': [{'description': 'Description_30',
#     'dificulty': 4,
#     'duration': 28800,
#     'id': 31,
#     'name': 'Trial_30'},
#    {'description': 'Description_27',
#     'dificulty': 3,
#     'duration': 230400,
#     'id': 28,
#     'name': 'Trial_27'},
#    {'description': 'Description_23',
#     'dificulty': 3,
#     'duration': 115200,
#     'id': 24,
#     'name': 'Trial_23'},
#    {'description': 'Description_66',
#     'dificulty': 7,
#     'duration': 201600,
#     'id': 67,
#     'name': 'Trial_66'},
#    {'description': 'Description_93',
#     'dificulty': 10,
#     'duration': 115200,
#     'id': 94,
#     'name': 'Trial_93'},
#    {'description': 'Description_47',
#     'dificulty': 5,
#     'duration': 230400,
#     'id': 48,
#     'name': 'Trial_47'},
#    {'description': 'Description_96',
#     'dificulty': 10,
#     'duration': 201600,
#     'id': 97,
# ...

# %%
trials = gauntlets[0]['trials']
trials
# Out:
# [{'description': 'Description_30',
#   'dificulty': 4,
#   'duration': 28800,
#   'id': 31,
#   'name': 'Trial_30'},
#  {'description': 'Description_27',
#   'dificulty': 3,
#   'duration': 230400,
#   'id': 28,
#   'name': 'Trial_27'},
#  {'description': 'Description_23',
#   'dificulty': 3,
#   'duration': 115200,
#   'id': 24,
#   'name': 'Trial_23'},
#  {'description': 'Description_66',
#   'dificulty': 7,
#   'duration': 201600,
#   'id': 67,
#   'name': 'Trial_66'},
#  {'description': 'Description_93',
#   'dificulty': 10,
#   'duration': 115200,
#   'id': 94,
#   'name': 'Trial_93'},
#  {'description': 'Description_47',
#   'dificulty': 5,
#   'duration': 230400,
#   'id': 48,
#   'name': 'Trial_47'},
#  {'description': 'Description_96',
#   'dificulty': 10,
#   'duration': 201600,
#   'id': 97,
#   'name': 'Trial_96'},
#  {'description': 'Description_39',
#   'dificulty': 4,
#   'duration': 288000,
#   'id': 40,
#   'name': 'Trial_39'},
#  {'description': 'Description_70',
# ...

# %%
participants = test_event['participants']
participants
# Out:
# [{'attribute_1': 1,
#   'attribute_2': 1,
#   'attribute_3': 8,
#   'attribute_4': 259200,
#   'attribute_5': 259200,
#   'name_1': 'First 78',
#   'name_2': 'Last 78'},
#  {'attribute_1': 1,
#   'attribute_2': 3,
#   'attribute_3': 6,
#   'attribute_4': 144000,
#   'attribute_5': 144000,
#   'name_1': 'First 254',
#   'name_2': 'Last 254'},
#  {'attribute_1': 1,
#   'attribute_2': 5,
#   'attribute_3': 9,
#   'attribute_4': 172800,
#   'attribute_5': 172800,
#   'name_1': 'First 485',
#   'name_2': 'Last 485'},
#  {'attribute_1': 1,
#   'attribute_2': 6,
#   'attribute_3': 5,
#   'attribute_4': 201600,
#   'attribute_5': 201600,
#   'name_1': 'First 546',
#   'name_2': 'Last 546'},
#  {'attribute_1': 1,
#   'attribute_2': 7,
#   'attribute_3': 10,
#   'attribute_4': 288000,
#   'attribute_5': 288000,
#   'name_1': 'First 699',
#   'name_2': 'Last 699'},
#  {'attribute_1': 1,
#   'attribute_2': 8,
#   'attribute_3': 2,
#   'attribute_4': 201600,
#   'attribute_5': 201600,
# ...

# %%
influencers = test_event['influencers']
influencers
# Out:
# [{'attribute_1': 8,
#   'attribute_2': 4,
#   'attribute_3': 2,
#   'attribute_4': 2,
#   'attribute_5': 0,
#   'name_1': 'Influencer_14622',
#   'name_2': 'Influencer_14622'}]
